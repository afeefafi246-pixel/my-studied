# %% [markdown]
# <a href="https://colab.research.google.com/github/afeefafi246-pixel/my-studied/blob/main/stone_paper_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome to my game")
user=input("enter stone , paper , scissor : ")

# %%
computer="stone"
print("welcome to my game")
print("enter stone , paper , scissor : ")
user=input( "user input : ")
print("computer input : ",computer)
if computer==user:
  print("tie")
elif(user=="scissor" and computer=="paper" ) or (user=="paper" and computer=="stone" ) or (user=="stone" and computer=="scissor"):
     print("you winn")
elif(user=="scissor" and computer=="stone") or(user=="paper" and computer=="scissor") or (user=="stone" and computer=="paper"):
     print("computer win")
else:
  print("invalid input! ,enter stone , paper or scissor")

# %%
import random
print("welcome to my game")
print("enter stone , paper , scissor : ")
choices=["stone","paper","scissor"]
computer=random.choice(choices)    #random.choice is used to randomly select a string from a list
user=input( "user input : ")
print("computer input : ",computer)
if computer==user:
  print("match is tie")
elif(user=="scissor" and computer=="paper" ) or (user=="paper" and computer=="stone" ) or (user=="stone" and computer=="scissor"):
     print("you winn")
elif(user=="scissor" and computer=="stone") or(user=="paper" and computer=="scissor") or (user=="stone" and computer=="paper"):
     print("computer win")
else:
  print("invalid user input! ,enter stone , paper or scissor")

# %%
import random
print("welcome to my game")
print("enter stone , paper , scissor : ")
choices=["stone","paper","scissor"]
computer=random.choice(choices)    #random.choice is used to randomly select a string from a list
while True:


   user=input( "user input : ")
   if user not in choices:            #when user input is not equal to choices then print the sentence
    print("invalid user input!, enter valid input like rock, paper, scissor")
    continue
   computer=random.choice(choices)
   print("computer input : ",computer)

   if computer==user:
    print("match is tie")
   elif(user=="scissor" and computer=="paper" ) or (user=="paper" and computer=="stone" ) or (user=="stone" and computer=="scissor"):
     print("you winn")

   else:
    print("computer win, your bad luck")

   play_again=input("do you want to continue the game  yes/no : ")
   if play_again!="yes":
     print("thanks for playing")
     break
# Out:
# welcome to my game
# enter stone , paper , scissor :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_15671/3406074031.py in <cell line: 0>()
#       7
#       8
# ----> 9    user=input( "user input : ")
#      10    if user not in choices:            #when user input is not equal to choices then print the sentence
#      11     print("invalid user input!, enter valid input like rock, paper, scissor")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...

# %%
import random
print("welcome to my game")
print("enter stone , paper , scissor : ")
choices=["stone","paper","scissor"]
computer=random.choice(choices)    #random.choice is used to randomly select a string from a list
while True:


   user=input( "user input : ")
   if user not in choices:            #when user input is not equal to choices then print the sentence
    print("invalid user input!, enter valid input like rock, paper, scissor")
    continue
   computer=random.choice(choices)
   print("computer input : ",computer)

   if computer==user:
    print("match is tie")
   elif(user=="scissor" and computer=="paper" ) or (user=="paper" and computer=="stone" ) or (user=="stone" and computer=="scissor"):
     print("you winn")

   else:
    print("computer win, your bad luck")

   play_again=input("do you want to continue the game  yes/no : ")
   if play_again!="yes":
     print("thanks for playing")
     break
# Out:
# welcome to my game
# enter stone , paper , scissor :
# user input : stone
# computer input :  paper
# computer win, your bad luck
# do you want to continue the game  yes/no : gdg
# thanks for playing
