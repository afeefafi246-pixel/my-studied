# %% [markdown]
# <a href="https://colab.research.google.com/github/afeefafi246-pixel/my-studied/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Atm:
   def __init__(self):
       self.balance=1000           #private variable
   def deposit(self, amount):
      if amount>0:
         self.__balance+=amount
         print("deposited:",amount)
      else:
         print("invalid balance")
   def withdraw(self, amount):
      if amount<=self.__balance:
         self.__balance-=amount
         print("withdrawn:",amount)
      else:
         print("insufficient balance")
   def check_balance(self):
      return self.__balance

# %% [markdown]
# print(atm.balance)

# %%
print(Atm.check_balance)
# Out:
# <function Atm.check_balance at 0x7b6cb5ea6fc0>

# %%
Atm.deposit(500)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2761/1776777221.py in <cell line: 0>()
# ----> 1 Atm.deposit(500)
#
# TypeError: Atm.deposit() missing 1 required positional argument: 'amount'
