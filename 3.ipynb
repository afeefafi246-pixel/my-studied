# %% [markdown]
# <a href="https://colab.research.google.com/github/afeefafi246-pixel/my-studied/blob/main/3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Car:
  def __init__(self,brand,color):       #__init__=constructor and create a object when it run automatically
    self.brand=brand                    #self=refer individual objects
    self.color=color

  def start(self):
    print(self.brand,"car started")

# %%
car1=Car("bmw","red")     #creating object
car2=Car("audi","black")  # ,,

print(car1.brand)         #calling
print(car2.color)
# Out:
# bmw
# black

# %%
class account:
  def __init__(self,name,balance):    #__init__;--initialize instance variable
    self.name=name
    self.balance=balance

  def deposite(self,amount):
    self.balance+=amount
    print("deposited:",amount)
  def check_balance(self):
    print("balance:",self.balance)

# %%
acc1=account("karthik",5000)   #creating object
acc2=account("ram",3000)       #,,

acc1.deposite(2000)            #calling
acc1.check_balance()
acc2.check_balance()
# Out:
# deposited: 2000
# balance: 7000
# balance: 3000

# %%
class mobile:
  def call(self):
    print("calling...")
  def message(self):

    print("sending message")
  def camera(self):
    print("taking photo")

# %%
m1=mobile()  #creating object
m1.call()    #calling method..
m1.message() #,,
m1.camera()  #,,
# Out:
# calling...
# sending message
# taking photo

# %%
class robot:
  def introduce(self):
    print("my name is alexa,from japan")
  def to_do(self):
    print("complete afeef home works")

# %%
r1=robot()
r1.introduce()
r1.to_do()
# Out:
# my name is alexa,from japan
# complete afeef home works

# %%
class movie_ticket:
  def __init__(self,name,movie,seat_number):
    self.name=name
    self.movie=movie
    self.seat_number=seat_number

  def start(self):
    print("name:",self.name)

    print("movie:",self.movie)

    print("seat_number:",self.seat_number)

# %%
m1=movie_ticket("afeef","naran",41)
m1.start()
# Out:
# name: afeef
# movie: naran
# seat_number: 41

# %%
def booking_details(name,movie,seat):
  print("name:",name)
  print("movie:",movie)
  print("seat:",seat)
print("movie ticket1:")
booking_details(name="afeef",movie="naran",seat=34)
# Out:
# movie ticket1:
# name: afeef
# movie: naran
# seat: 34

# %%
class collage:                         #outer class

   class student:                        #inner class
    def __init__(self,name,roll):
       self.name=name
       self.roll=roll
    def display(self):
       print("name:",self.name)
       print("roll:",self.roll)
s1=collage.student("sinan",27)
s1.display()
# Out:
# name: sinan
# roll: 27

# %%
class company:                         #outer class
   def __init__(self,cname):
     self.cname=cname
   class employee:                        #inner class
    def __init__(self,Ename):
       self.Ename=Ename

    def display(self):
       print("Ename:",self.Ename)
c=company("TCS")
e=c.employee("ANU")
e.display()
# Out:
# Ename: ANU

# %%
class hospital:
  def __init__(self,Hname):
    self.Hname=Hname
  def show(self):
     print("Hname:",self.Hname)
  class doctor:
    def __init__(self,name,specialised):
      self.name=name
      self.specialised=specialised
    def show(self):
      print("name:",self.name)
      print("specialised:",self.specialised)

H=hospital("wims")
S=H.doctor("HARSHAN","thyroid")
H.show()
S.show()
# Out:
# Hname: wims
# name: HARSHAN
# specialised: thyroid

# %%
#creating a parent class
class animal:
  def eat(self):
    print("this animal eat food")

# %%
#creatin child class
class dog(animal):
  def bark(self):
    print("dog bark")
#
d=dog()
d.eat()
d.bark()
# Out:
# this animal eat food
# dog bark

# %%
class giraffe(animal):
  def height(self):
    print("giraffe is big height")

g=giraffe()
g.eat()
g.height()
# Out:
# this animal eat food
# giraffe is big height

# %%
#parent class
class user():
  def login(self):
    print("new profile was logined in insta")

#child class1
class student(user):
  def student(self):
    print("student is watch a video")
#child class2
class teacher(user):
  def teacher(seif):
    print("teacher upload a video")

s=student()  #calling child 1
s.login()    #calling parent on child 1
s.student()  #calling
t=teacher()  #calling teacher
t.teacher()  #calling
# Out:
# new profile was logined in insta
# student is watch a video
# teacher upload a video

# %%
class father:
  def skill1(self):
    print("father's skill:gardening")

class mother:
  def skill2(self):
    print("mother's skill:coocking")

class child(father,mother):
  def skill(self):
    print("my skill:runnuing")
c=child()
c.skill1()
c.skill2()
c.skill()
# Out:
# father's skill:gardening
# mother's skill:coocking
# my skill:runnuing

# %%
                                   #multiple inheritence

#parent class 1
class father:
  def skill1(self):
    print("father's skill:gardening")
#parent class 2
class mother:
  def skill2(self):
    print("mother's skill:coocking")
#child class
class child(father,mother):
  pass #pass is used to skip the error

c=child()
c.skill1()
c.skill2()
# Out:
# father's skill:gardening
# mother's skill:coocking

# %%
                             #multi level inheritence

#grandparent class
class grandParent():
  def display(self):
    print("grandParent calss")

#parent class inherits from grendParent
class parent(grandParent):
  def show(self):
    print("parent class")

#child class inherits from parent class
class child(parent):
  def see(self):
    print("child class")

#create objrect of child
obj=child()
obj.display()
obj.show()
obj.see()
# Out:
# grandParent calss
# parent class
# child class

# %%
#parent class
class animal():
  def eat(self):
    print("animal eat food")

#child class1
class dog(parent):
  def bark(self):
    print("dog bark")
#child class2
class cat(parent):
  def meow(seif):
    print("cat meow")

s=dog()  #calling child 1
s.eat()    #calling parent on child 1
s.bark()  #calling
t=cat()  #calling teacher
t.eat()
t.meow()  #calling
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2303/4117961920.py in <cell line: 0>()
#      14
#      15 s=dog()  #calling child 1
# ---> 16 s.eat()    #calling parent on child 1
#      17 s.bark()  #calling
#      18 t=cat()  #calling teacher
#
# AttributeError: 'dog' object has no attribute 'eat'

# %%
#base class
class animal:
  def eat(self):
    print("animal eat")

#derived class(single inheritence)
class mammals(animal):
  def walk(self):
    print("mammals walks")

#another base class
class pet:
  def play(slef):
    print("pet plays")

#derived class(multiple inheritence)
class dog(mammals,pet):
  def bark(self):
    print("dog barks")

#create objrect
d=dog()

#callig method
d.eat()
d.walk()
d.play()
d.bark()
# Out:
# animal eat
# mammals walks
# pet plays
# dog barks

# %%
class Employee:
   def __init__(self):
      self.__salary=50000            #private attribute

   def get_salary(self):            #getter method
      return self.__salary

   def set_salary(self,amount):     #setter method
      if amount>0:
         self.__salary=amount
      else:
         Print("invalid salary amount!")

emp=Employee()
print(emp.get_salary())         #access salary using getter
emp.set_salary(60000)           #update salary using setter
print(emp.get_salary())
# Out:
# 50000
# 60000
