# %% [markdown]
# <a href="https://colab.research.google.com/github/afeefafi246-pixel/my-studied/blob/main/1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=20
y=a+b
print(y)
# Out:
# 30

# %%
m=10
m+=10
print(k)
# Out:
# 20

# %%
m=10
m-=10
print(m)
# Out:
# 0

# %%
m=10
m*=10
print(m)
# Out:
# 100

# %%
a=10
b=5
print(a>b)
# Out:
# True

# %%
a=10
b=20
print(a<=b)
# Out:
# True

# %%
5>=2
# Out:
# True

# %%
x=True
y=false
print(xandy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-935311056.py in <cell line: 0>()
#       1 x=True
# ----> 2 y=false
#       3 print(xandy)
#
# NameError: name 'false' is not defined
