# %% [markdown]
# <a href="https://colab.research.google.com/github/afeefafi246-pixel/my-studied/blob/main/guess_my_number_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("guess a number"))
if num==88:
  print(())

# %%
print("welcome to gussing my number")
secret_number=55
user_number=int(input("guess a number : "))
if user_number==secret_number:
   print("congratulation, your guess is correct")
else:
   print("you guess wrong number")
# Out:
# welcome to gussing my number
# guess a number : 55
# congratulation, your guess is correct

# %%
print("welcome to gussing my number")
secret_number=55
for i in range(1,7):   #for loop is used to until limited attempt
 user_number=int(input("guess a number : "))
 if user_number==secret_number:
   print("congratulation, your guess is correct")
   break
else:
   print("your attempt is over, try again")
# Out:
# welcome to gussing my number
# guess a number : 55
# congratulation, your guess is correct

# %%
print("welcome to gussing my number")
secret_number=55
for i in range(0,secret_number):
 user_number=int(input("guess a number : "))
 if user_number==secret_number:
   print("congratulation, your guess is correct")
   break
else:
   print("your attempt is over, try again")
# Out:
# welcome to gussing my number
# guess a number : 5
# guess a number : 7
# guess a number : 8
# guess a number : 9
# guess a number : 0
# guess a number : 5
# guess a number : 4
# guess a number : 6
# guess a number : 55
# congratulation, your guess is correct

# %% [markdown]
# LEVEL 3

# %%
print("welcome to gussing my number")
secret_number=55
while True:     #while true is used to repeat the condition when it is true

 user_number=int(input("guess a number : "))
 if user_number==secret_number:
   print("congratulation, your guess is correct")
   break
else:
   print("your attempt is over, try again")
# Out:
# welcome to gussing my number
# guess a number : 7
# guess a number : 8
# guess a number : 5
# guess a number : 4
# guess a number : 3
# guess a number : 5
# guess a number : 7
# guess a number : 9
# guess a number : 55
# congratulation, your guess is correct

# %%
print("welcome to gussing my number")
print("enter number between 1 to 100")
secret_number=55
while True:
 num=int(input("guess a number : "))
 if num==secret_number:
   print("congratulation, your guess is correct")
   break
 elif num>100:
   print("invalid number")
 elif num<1:
   print("inavalid number")
 elif num>secret_number:
  print("my number is less your guess")

 else:
   print("my number is greater than your guess")
# Out:
# welcome to gussing my number
# enter number between 1 to 100

# %%
print("welcome to gussing my number")
print("enter number between 1 to 100")
secret_number=55
for i in range(1,8):
 num=int(input("guess a number : "))
 if num>100 or num<1:
   print("invalid number, enter number between 1 and 100")
 elif num>secret_number:
  print("my number is less your guess")
 elif num<secret_number:
  print("my number is higher your guess")
 else:
  print("congratulation your guess is correct")
  print(f"congratulation your guess {secret_number} is correct in {i} attempt")
  break
# Out:
# welcome to gussing my number
# enter number between 1 to 100
# guess a number : 55
# congratulation your guess is correct
# congratulation your guess 55 is correct in 1 attempt

# %%
print("welcome to gussing my number")
print("enter number between 1 to 100")
secret_number=55
for i in range(1,8):
 num=int(input("guess a number : "))
 if num>100 or num<1:
   print("invalid number, enter number between 1 and 100")
 elif num>secret_number:
  print("my number is less your guess")
 elif num<secret_number:
  print("my number is higher your guess")
 else:
  print("congratulation your guess is correct")
  print(f"congratulation your guess {secret_number} is correct in {i} attempt")
  break
else:
  print("your attempt is over and try again")
# Out:
# welcome to gussing my number
# enter number between 1 to 100
# guess a number : 55
# congratulation your guess is correct
# congratulation your guess 55 is correct in 1 attempt

# %%
import random  #impoer random is used to select a number in randomly but the number is not see in code and not know the user
print("welcome to gussing my number")
print("enter number between 1 to 100")
secret_number=random.randint(1,100)

for i in range(1,8):
 num=int(input("guess a number : "))

 if num>100 or num<1:
   print("invalid number, enter number between 1 and 100")
 elif num>secret_number:
  print("my number is less your guess")
 elif num<secret_number:
  print("my number is higher your guess")

 else:
  print("congratulation your guess is correct")
  print(f"congratulation your guess {secret_number} is correct in {i} attempt")
  break
else:
  print("your attempt is over and try again")
# Out:
# welcome to gussing my number
# enter number between 1 to 100
# guess a number : der
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_793/1502641682.py in <cell line: 0>()
#       4 secret_number=random.randint(1,100)
#       5 for i in range(1,8):
# ----> 6  num=int(input("guess a number : "))
#       7  if num>100 or num<1:
#       8    print("invalid number, enter number between 1 and 100")
#
# ValueError: invalid literal for int() with base 10: 'der'

# %% [markdown]
# how to remove error in the below code,the wrong is when we type char instead of intiger

# %%
40
import random  #impoer random is used to select a number in randomly but the number is not see in code and not know the user
print("welcome to gussing my number")
print("enter number between 1 to 100")
secret_number=random.randint(1,100)

for i in range(1,8):
  try:                                      #try-except block is used to remove error when enter char instead of intiger
    num=int(input("guess a number : "))
  except ValueError:
    print("invalid input!, please enter a number")
    continue
  if num>100 or num<1:
   print("invalid number, enter number between 1 and 100")
  elif num>secret_number:
   print("my number is less your guess")
  elif num<secret_number:
   print("my number is higher your guess")

  else:
   print("congratulation your guess is correct")
   print(f"congratulation your guess {secret_number} is correct in {i} attempt")
   break
else:
  print("your attempt is over and try again")
# Out:
# welcome to gussing my number
# enter number between 1 to 100
# guess a number : 34
# my number is less your guess

# %%
40
import random  #impoer random is used to select a number in randomly but the number is not see in code and not know the user
print("welcome to gussing ")
print("enter number between 1 to 100")
secret_number=random.randint(1,100)

for i in range(1,8):
  try:                                      #try-except block is used to remove error when enter char instead of intiger
    num=int(input("guess a number : "))
  except ValueError:
    print("invalid input!, please enter a number")
    continue
  if num>100 or num<1:
   print("invalid number, enter number between 1 and 100")
  elif num>secret_number:
   print("my number is less your guess")
  elif num<secret_number:
   print("my number is higher your guess")

  else:
   print("congratulation your guess is correct")
   print(f"congratulation your guess {secret_number} is correct in {i} attempt")
   break
else:
  print("your attempt is over and try again")
